# %% [markdown]
# # Ikamva Lam — hackathon overview (TASKS §16.4)
#
# - **Repo:** learner Flutter app with **on-device Gemma** via `flutter_gemma` (bundled **`.litertlm`** in **`pubspec.yaml`** assets; see `assets/models/OBTAINING_MODELS.txt` and `learner_app/docs/model_delivery.md`).
# - **Run locally:** `cd learner_app && flutter pub get && flutter run` (optional empty repo-root **`.env`** if your launch config uses **`--dart-define-from-file`**).
# - **Optional:** stub LLM with `IKAMVA_USE_STUB_LLM=1` for CI and notebooks without on-device weights.

# %%
# Optional: smoke-check JSON export shape (requires Python 3)
import json
sample = {
  "learner_id": "demo",
  "sessions_total": 1,
  "top_weak_skills": []
}
print(json.dumps(sample, indent=2))
