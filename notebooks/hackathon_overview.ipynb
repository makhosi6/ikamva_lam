# %% [markdown]
# # Ikamva Lam — hackathon overview (TASKS §16.4)
#
# - **Repo:** learner Flutter app with **on-device Gemma** via `flutter_gemma` (`.task` downloaded over HTTPS; see `assets/models/OBTAINING_MODELS.txt` and `IKAMVA_MODEL_DOWNLOAD_URL`).
# - **Run locally:** `cd learner_app && flutter pub get && flutter run` (configure `.env` / `--dart-define-from-file` for a model URL on device).
# - **Optional:** stub LLM with `IKAMVA_USE_STUB_LLM=1` for CI and notebooks without a device download.

# %%
# Optional: smoke-check JSON export shape (requires Python 3)
import json
sample = {
  "learner_id": "demo",
  "sessions_total": 1,
  "top_weak_skills": []
}
print(json.dumps(sample, indent=2))
