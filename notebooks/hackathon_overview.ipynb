# %% [markdown]
# # Ikamva Lam — hackathon overview (TASKS §16.4)
#
# - **Repo:** learner Flutter app + `native/` llama.cpp notes.
# - **Run locally:** `cd learner_app && flutter pub get && flutter run`.
# - **Optional:** stub LLM with `IKAMVA_USE_STUB_LLM=1` for CI and notebooks without GGUF.

# %%
# Optional: smoke-check JSON export shape (requires Python 3)
import json
sample = {
  "learner_id": "demo",
  "sessions_total": 1,
  "top_weak_skills": []
}
print(json.dumps(sample, indent=2))
